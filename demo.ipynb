# %%
from matplotlib.pyplot import imshow
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams['figure.figsize'] = [12,6]

import os, sys, glob
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # supress TF warning
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # only use GPU #
from PIL import Image
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras import Model
from tensorflow.keras import losses
from sklearn.feature_extraction.image import extract_patches_2d, reconstruct_from_patches_2d
from skimage.util import view_as_blocks
import io

from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Lambda, Reshape, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

import tensorflow as tf

#from utils import save_batch_imgs, ray, structural_similarity
from dahuffman import HuffmanCodec


from utils import slice_image_4d, combine_image_4d
from net import build_enc_patch, build_dec_patch, UniformNoise, save_q_model, infer_q_tflite_single_local, split_k210_model

import ray
ray.init()
# Out:
# 2021-02-18 21:12:15,211	INFO resource_spec.py:212 -- Starting Ray with 17.24 GiB memory available for workers and up to 8.64 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2021-02-18 21:12:15,523	INFO services.py:1170 -- View the Ray dashboard at localhost:8265
# {'node_ip_address': '10.138.0.13',
#  'raylet_ip_address': '10.138.0.13',
#  'redis_address': '10.138.0.13:64105',
#  'object_store_address': '/tmp/ray/session_2021-02-18_21-12-15_210178_11553/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-02-18_21-12-15_210178_11553/sockets/raylet',
#  'webui_url': 'localhost:8265',
#  'session_dir': '/tmp/ray/session_2021-02-18_21-12-15_210178_11553'}

# %%
# Define experiment parameters

target_list = ["MS_SSIM", "VGG_Loss", "Classification_Accuracy"]
train_target = 0
eval_target = 0

dataset_list = ["cars", "flowers", "birds", "caltech101"]
dataset_idx = 0
dataset_name = dataset_list[dataset_idx]
print("Train target: %s, eval tareget: %s, dataset: %s." % 
      (target_list[train_target], target_list[eval_target], dataset_name))
# Out:
# Train target: MS_SSIM, eval tareget: MS_SSIM, dataset: cars.

# %% [markdown]
# ## Step 1. Build patch autoencoder
# ### 1.1 Build encoder and decoder respectively
# ### 1.2 Sanity check model could be compiled and converted

# %%
pw = 8    # pad width
input_h, input_w = 112, 112
enc_c = [64, 64, 64, 4]
dec_c = [64, 64, 64, 64]

# build encoder with 4 conv layers
enc_patch, embed_size = build_enc_patch(Input(shape=(input_h, input_w, 3), name='enc_input'), enc_c , 8)
print(enc_patch.summary())

# build decoder with 4 conv layers
dec_patch = build_dec_patch(Input(shape=(embed_size[1]), name='dec_input'), dec_c, 4, input_h, input_w, 8)
print(dec_patch.summary())


# build autoencoder that process a patch
nn_in = Input(shape=(input_h, input_w, 3), name='patch_input')  # adapt this if using `channels_first` image data format
x = enc_patch(nn_in)
x = UniformNoise(minval=-0.01, maxval=0.01, name='noise')(x)
x = dec_patch(x)
autoencoder_patch = Model(nn_in, x)

print(autoencoder_patch.summary())
print(autoencoder_patch(np.zeros((10,112,112,3))).shape)    # check model dimension
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# enc_input (InputLayer)       [(None, 112, 112, 3)]     0
# _________________________________________________________________
# pad (ZeroPadding2D)          (None, 128, 128, 3)       0
# _________________________________________________________________
# econv1 (Conv2D)              (None, 128, 128, 64)      1792
# _________________________________________________________________
# econv2 (Conv2D)              (None, 64, 64, 64)        36928
# _________________________________________________________________
# econv3 (Conv2D)              (None, 32, 32, 64)        36928
# _________________________________________________________________
# econv4 (Conv2D)              (None, 16, 16, 4)         2308
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# =================================================================
# Total params: 77,956
# Trainable params: 77,956
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dec_input (InputLayer)       [(None, 1024)]            0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 4)         0
# _________________________________________________________________
# dconv1 (Conv2D)              (None, 16, 16, 64)        2368
# _________________________________________________________________
# tf_op_layer_ResizeNearestNei [(None, 32, 32, 64)]      0
# _________________________________________________________________
# dconv2 (Conv2D)              (None, 32, 32, 64)        36928
# _________________________________________________________________
# tf_op_layer_ResizeNearestNei [(None, 64, 64, 64)]      0
# _________________________________________________________________
# dconv3 (Conv2D)              (None, 64, 64, 64)        36928
# _________________________________________________________________
# tf_op_layer_ResizeNearestNei [(None, 128, 128, 64)]    0
# _________________________________________________________________
# dconv4 (Conv2D)              (None, 128, 128, 64)      36928
# _________________________________________________________________
# dout (Conv2D)                (None, 128, 128, 3)       1731
# _________________________________________________________________
# crop (Cropping2D)            (None, 112, 112, 3)       0
# =================================================================
# Total params: 114,883
# Trainable params: 114,883
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# patch_input (InputLayer)     [(None, 112, 112, 3)]     0
# _________________________________________________________________
# model (Model)                (None, 1024)              77956
# _________________________________________________________________
# noise (UniformNoise)         (None, 1024)              0
# _________________________________________________________________
# model_1 (Model)              (None, 112, 112, 3)       114883
# =================================================================
# Total params: 192,839
# Trainable params: 192,839
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:Layer pad is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# (10, 112, 112, 3)

# %%
# optional check to make sure model runs on K210. Requires TF1.15!

save_q_model(autoencoder_patch, "test.tflite", np.random.random((100,112,112,3)).astype(np.float32))
# !edgetpu_compiler test.tflite

k_in = Input(batch_shape=(1, input_h, input_w, 3), name='k210_in')
x = enc_patch(k_in)
x = dec_patch(x)
k210_ae = Model(k_in, x)
# optional visualization
tf.keras.utils.plot_model(k210_ae, show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)

k210_ae.save('k210_ae_test.h5')
# !CUDA_VISIBLE_DEVICES=-1 /home/stanfordsnsg/TF1/bin/tflite_convert --enable_v1_converter --output_file k210_ae_test.tflite --keras_model_file k210_ae_test.h5
# !./K210/ncc compile k210_ae_test.tflite k210_ae_test.kmodel -i tflite -o kmodel --dataset ./Dataset/cal/ --inference-type uint8 --max-allocator-solve-secs 3

print(os.path.getsize("k210_ae_test.kmodel"))
# Out:
# Saved quantized tflite model test.tflite
# Edge TPU Compiler version 2.1.302470888
#
# Model compiled successfully in 88 ms.
#
# Input model: test.tflite
# Input size: 204.35KiB
# Output model: test_edgetpu.tflite
# Output size: 268.81KiB
# On-chip memory used for caching model parameters: 194.75KiB
# On-chip memory remaining for caching model parameters: 6.71MiB
# Off-chip memory used for streaming uncached model parameters: 0.00B
# Number of Edge TPU subgraphs: 1
# Total number of operations: 17
# Operation log: test_edgetpu.log
#
# Model successfully compiled but not all operations are supported by the Edge TPU. A percentage of the model will instead run on the CPU, which is slower. If possible, consider updating your model to use only operations supported by the Edge TPU. For details, visit g.co/coral/model-reqs.
# Number of operations that will run on Edge TPU: 15
# Number of operations that will run on CPU: 2
# See the operation log file for individual operation details.
# WARNING:tensorflow:From /home/stanfordsnsg/TF1/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# W0218 21:12:26.034237 139829136684416 deprecation.py:506] From /home/stanfordsnsg/TF1/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# W0218 21:12:26.295586 139829136684416 backend.py:548] OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# 2021-02-18 21:12:26.302562: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# W0218 21:12:26.414010 139829136684416 hdf5_format.py:171] No training configuration found in save file: the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:From /home/stanfordsnsg/TF1/lib/python3.7/site-packages/tensorflow_core/lite/python/util.py:249: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0218 21:12:26.438202 139829136684416 deprecation.py:323] From /home/stanfordsnsg/TF1/lib/python3.7/site-packages/tensorflow_core/lite/python/util.py:249: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/stanfordsnsg/TF1/lib/python3.7/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0218 21:12:26.438392 139829136684416 deprecation.py:323] From /home/stanfordsnsg/TF1/lib/python3.7/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 18 variables.
# I0218 21:12:26.460185 139829136684416 graph_util_impl.py:334] Froze 18 variables.
# INFO:tensorflow:Converted 18 variables to const ops.
# I0218 21:12:26.463637 139829136684416 graph_util_impl.py:394] Converted 18 variables to const ops.
# 2021-02-18 21:12:26.469937: E tensorflow/core/grappler/grappler_item_builder.cc:656] Init node econv1/kernel/Assign doesn't exist in graph
# 1. Import graph...
# 2. Optimize Pass 1...
# 3. Optimize Pass 2...
# 4. Quantize...
#   4.1. Add quantization checkpoints...
#   4.2. Get activation ranges...
#   Plan buffers...
#   Run calibration...
#   [==================================================] 100% 9.369s
#   4.5. Quantize graph...
# 5. Lowering...
# 6. Generate code...
#   Plan buffers...
#   Emit code...
# Main memory usage: 2113536 B
#
# SUMMARY
# INPUTS
# 0	k210_in	1x3x112x112
# OUTPUTS
# 0	model_1/crop/strided_slice	1x3x112x112
# 202736

# %% [markdown]
# ## Step 2. Build and train full image autoencoder
# ### 2.1 Build full autoencoder on top of batch autoencoder
# ### 2.2 Load dataset and preprocessing
# ### 2.3 Define loss functions
# ### 2.4 Train model

# %%
x = Input(shape=(input_h*2, input_w*2, 3), name='full_input')  # adapt this if using `channels_first` image data format
img_slices = [None]*4
img_slices[0] = tf.slice(x, [0, 0, 0, 0],             [-1, input_h, input_w, 3])
img_slices[1] = tf.slice(x, [0, 0, input_w, 0],       [-1, input_h, input_w, 3])
img_slices[2] = tf.slice(x, [0, input_h, 0, 0],       [-1, input_h, input_w, 3])
img_slices[3] = tf.slice(x, [0, input_h, input_w, 0], [-1, input_h, input_w, 3])


model_patch = [None]*4
img_outs = [None]*4
for i in range(4):
    img_outs[i] = autoencoder_patch(img_slices[i])

img_all = tf.concat([tf.concat([img_outs[0], img_outs[1]], axis=2), tf.concat([img_outs[2], img_outs[3]], axis=2)], axis=1)

autoencoder = Model(x, img_all)
print(autoencoder.summary())

# requires pydot, pydotplus, graphvis and apt-get install graphviz
#tf.keras.utils.plot_model(autoencoder, show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)

#plt.imshow(autoencoder(x_test[:10])[0])
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# full_input (InputLayer)         [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Slice (TensorFlowOp [(None, 112, 112, 3) 0           full_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_1 (TensorFlow [(None, 112, 112, 3) 0           full_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_2 (TensorFlow [(None, 112, 112, 3) 0           full_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_3 (TensorFlow [(None, 112, 112, 3) 0           full_input[0][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 112, 112, 3)  192839      tf_op_layer_Slice[0][0]
#                                                                  tf_op_layer_Slice_1[0][0]
#                                                                  tf_op_layer_Slice_2[0][0]
#                                                                  tf_op_layer_Slice_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 112, 224, 3) 0           model_2[1][0]
#                                                                  model_2[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, 112, 224, 3) 0           model_2[3][0]
#                                                                  model_2[4][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 224, 224, 3) 0           tf_op_layer_concat[0][0]
#                                                                  tf_op_layer_concat_1[0][0]
# ==================================================================================================
# Total params: 192,839
# Trainable params: 192,839
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
dataset_fn = "./Dataset/%s_224_224_color.npy" % dataset_name
train_list = sorted( glob.glob("./Dataset/%s/split_train/*.jpg" % dataset_name) )
test_list = sorted( glob.glob("./Dataset/%s/split_test/*.jpg" % dataset_name) )

if os.path.exists(dataset_fn):
    x_train, x_test = np.load(dataset_fn, allow_pickle=True)
    print("Loaded prepared dataset: " + dataset_fn)
else:
    
    @ray.remote
    def proc_img(f):
        #  width, height in PIL
        img = Image.open(f).convert('RGB').resize((224,224), resample=Image.LANCZOS)
        return np.array(img)
    
    x_train = np.array(ray.get([proc_img.remote(x) for x in train_list]))
    x_test  = np.array(ray.get([proc_img.remote(x) for x in  test_list]))
    
    np.save(dataset_fn, [x_train, x_test])

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

print(x_train.shape, x_test.shape)
# Out:
# Loaded prepared dataset: ./Dataset/cars_224_224_color.npy
# (6516, 224, 224, 3) (1628, 224, 224, 3)

# %%
## Load VGG model

from tensorflow.keras.applications.vgg16 import VGG16
vgg16 = VGG16(weights='imagenet', include_top=False)
for layer in vgg16.layers:
    layer.trainable = False
#print(vgg16.summary())
vggs = Model(inputs=vgg16.input, outputs=vgg16.get_layer("block2_conv2").output)
#print(vggs.summary())
print(vggs(np.zeros((1,224,224,3))).shape )  # check if model works


## Load Classification model

car_model = load_model('./SavedModel/model_cars/model_0.9797.h5')
for layer in car_model.layers:
    layer.trainable = False
        
# Get labels of training and test for classification
from scipy.io import loadmat
cars_train_annos = loadmat('./Dataset/cars/devkit/cars_train_annos.mat')['annotations'][0]
cars_train_label = [c[4][0][0] - 1 for c in cars_train_annos]    # add offset 1 to make index start from 0
cars_classes = len(list(set(cars_train_label)))

train_list_label = [ cars_train_label[i-1] for i in [int(l.split('/')[-1].split('.')[0]) for l in train_list]] 
test_list_label = [ cars_train_label[i-1] for i in [int(l.split('/')[-1].split('.')[0]) for l in test_list]]
train_list_label_cat = tf.keras.utils.to_categorical(np.repeat(train_list_label, 25), cars_classes)
test_list_label_cat = tf.keras.utils.to_categorical(np.repeat(test_list_label, 25), cars_classes)


## following are assorted loss functions

def msssim_loss(y_true, y_pred):
    return tf.constant(1.0) - tf.reduce_mean(tf.image.ssim_multiscale(y_true, y_pred, 1.0))


def ssim_loss(y_true, y_pred):
    return tf.constant(1.0) - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

def ssim_loss_flatten(y_true, y_pred):
    return ssim_loss(tf.reshape(y_true, [tf.shape(y_true)[0], 56, 72, 3]), y_pred)


def classification_loss_single(y_true, y_pred):
    loss = tf.keras.losses.categorical_crossentropy(car_model(y_true*2.0-1.0), car_model(y_pred*2.0-1.0))
    return tf.reduce_mean(loss, axis=-1)


def ssim_classification_loss_single(y_true, y_pred):
    ssim_loss = 1.0 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))
    class_loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(car_model(y_true*2.0-1.0), car_model(y_pred*2.0-1.0)))
    return ssim_loss + 1.1*class_loss


def input_ssim_classification_loss_single(x_true): 
    def loss_helper(y_true, y_pred):   # y_true is None
        #y_true = x_true
        return ssim_classification_loss_single(x_true, y_pred)
    return loss_helper


# hybrid loss need hybrid label
# np.concatenate((x_train[:1000].reshape(1000, 56*72*3), train_list_label_cat[:1000]), axis=-1)
def ssim_classification_loss(y_true, y_pred):
    x_train = y_true[:,:56*72*3]
    train_list_label_cat = y_true[:,56*72*3:]
    return 1.0*ssim_loss_flatten(x_train, y_pred) + 0.1*classification_loss(train_list_label_cat, y_pred)

#def vgg16_loss(y_true, y_pred):
#    return tf.keras.losses.MSE(vgg16(y_true*2.0-1.0), vgg16(y_pred*2.0-1.0))

def vgg16_loss(y_true, y_pred):
    m = tf.keras.losses.MSE(vgg16(y_true*2.0-1.0), vgg16(y_pred*2.0-1.0))
    return tf.reduce_mean(tf.reduce_mean(m, -1),-1)

def input_vgg16_loss(x_true):
    def loss_helper(y_true, y_pred):   # y_true is None
        #y_true = x_true
        return vgg16_loss(x_true, y_pred)
    return loss_helper


def vggs_loss(y_true, y_pred):
    return tf.keras.losses.MSE(vggs(y_true*2.0-1.0), vggs(y_pred*2.0-1.0))
# Out:
# WARNING:tensorflow:Layer block1_conv1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# (1, 112, 112, 128)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    rotation_range=15,
    width_shift_range=.15,
    height_shift_range=.15,
    horizontal_flip=True,
    vertical_flip=True)
train_gen.fit(x_train, augment=True)

#x_train_gen = next(train_gen.flow(x_train, batch_size=5120))

model_path = "./SavedModel/%s" % dataset_name
os.system("mkdir -p " + model_path)
best_model = "./SavedModel/%s/single_shot_no_fc_msssim_loss_1024_57.h5" % dataset_name

class PredictionCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        #global x_train_gen, x_test
        #x_train_gen = next(train_gen.flow(x_train, batch_size=5120))
        
        plt.figure(figsize=(4,2))
        plt.subplot(1,2,1); plt.imshow(x_test[2])
        plt.subplot(1,2,2); plt.imshow(autoencoder.predict(x_test[:10])[2])
        plt.show()
        
        loss_fn = str(autoencoder.loss).split(' ')[1]
        autoencoder.save_weights(model_path + '/single_shot_no_fc_%s_1024_%d.h5' % (loss_fn, epoch))
        return True


autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                    loss = [msssim_loss, vgg16_loss, classification_loss_single][train_target],
                    metrics=[msssim_loss, vgg16_loss, classification_loss_single])

if os.path.exists(best_model):
    autoencoder.load_weights(best_model)
else:
    history = autoencoder.fit(zip(train_gen.flow(x_train, batch_size=64, seed=0), train_gen.flow(x_train, batch_size=64, seed=0)),
                        epochs=100,
                        steps_per_epoch=500,
                        #batch_size=32,
                        verbose=1,
                        shuffle=True,
                        validation_data=(x_test[:], x_test[:]),
                        #use_multiprocessing=True,
                        #workers=4,
                        callbacks=[PredictionCallback()])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 500 steps, validate on 1628 samples
# Epoch 1/100
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:303: setdiff1d (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# This op will be removed after the deprecation date. Please switch to tf.sets.difference().
# 499/500 [============================>.] - ETA: 1s - loss: 0.1049 - msssim_loss: 0.1049 - vgg16_loss: 0.0908 - classification_loss_single: 4.7463
# 500/500 [==============================] - 1001s 2s/step - loss: 0.1048 - msssim_loss: 0.1048 - vgg16_loss: 0.0907 - classification_loss_single: 4.7452 - val_loss: 0.0716 - val_msssim_loss: 0.0716 - val_vgg16_loss: 0.0878 - val_classification_loss_single: 3.3841
# Epoch 2/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0562 - msssim_loss: 0.0562 - vgg16_loss: 0.0733 - classification_loss_single: 4.2007
# 500/500 [==============================] - 962s 2s/step - loss: 0.0562 - msssim_loss: 0.0562 - vgg16_loss: 0.0733 - classification_loss_single: 4.2007 - val_loss: 0.0643 - val_msssim_loss: 0.0644 - val_vgg16_loss: 0.0833 - val_classification_loss_single: 3.0440
# Epoch 3/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0513 - msssim_loss: 0.0513 - vgg16_loss: 0.0690 - classification_loss_single: 4.0405
# 500/500 [==============================] - 962s 2s/step - loss: 0.0513 - msssim_loss: 0.0513 - vgg16_loss: 0.0690 - classification_loss_single: 4.0400 - val_loss: 0.0607 - val_msssim_loss: 0.0607 - val_vgg16_loss: 0.0799 - val_classification_loss_single: 2.8692
# Epoch 4/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0486 - msssim_loss: 0.0486 - vgg16_loss: 0.0656 - classification_loss_single: 3.9433
# 500/500 [==============================] - 962s 2s/step - loss: 0.0486 - msssim_loss: 0.0486 - vgg16_loss: 0.0656 - classification_loss_single: 3.9427 - val_loss: 0.0592 - val_msssim_loss: 0.0592 - val_vgg16_loss: 0.0783 - val_classification_loss_single: 2.7400
# Epoch 5/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0471 - msssim_loss: 0.0471 - vgg16_loss: 0.0640 - classification_loss_single: 3.8921
# 500/500 [==============================] - 962s 2s/step - loss: 0.0471 - msssim_loss: 0.0471 - vgg16_loss: 0.0640 - classification_loss_single: 3.8926 - val_loss: 0.0573 - val_msssim_loss: 0.0573 - val_vgg16_loss: 0.0766 - val_classification_loss_single: 2.6798
# Epoch 6/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0459 - msssim_loss: 0.0459 - vgg16_loss: 0.0627 - classification_loss_single: 3.8504
# 500/500 [==============================] - 962s 2s/step - loss: 0.0459 - msssim_loss: 0.0459 - vgg16_loss: 0.0627 - classification_loss_single: 3.8508 - val_loss: 0.0558 - val_msssim_loss: 0.0558 - val_vgg16_loss: 0.0746 - val_classification_loss_single: 2.6096
# Epoch 7/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0450 - msssim_loss: 0.0450 - vgg16_loss: 0.0616 - classification_loss_single: 3.7988
# 500/500 [==============================] - 962s 2s/step - loss: 0.0450 - msssim_loss: 0.0450 - vgg16_loss: 0.0616 - classification_loss_single: 3.7992 - val_loss: 0.0546 - val_msssim_loss: 0.0546 - val_vgg16_loss: 0.0732 - val_classification_loss_single: 2.4971
# Epoch 8/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0440 - msssim_loss: 0.0440 - vgg16_loss: 0.0606 - classification_loss_single: 3.7674
# 500/500 [==============================] - 962s 2s/step - loss: 0.0440 - msssim_loss: 0.0440 - vgg16_loss: 0.0606 - classification_loss_single: 3.7676 - val_loss: 0.0550 - val_msssim_loss: 0.0550 - val_vgg16_loss: 0.0737 - val_classification_loss_single: 2.4908
# Epoch 9/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0434 - msssim_loss: 0.0434 - vgg16_loss: 0.0598 - classification_loss_single: 3.7533
# 500/500 [==============================] - 962s 2s/step - loss: 0.0434 - msssim_loss: 0.0434 - vgg16_loss: 0.0598 - classification_loss_single: 3.7527 - val_loss: 0.0534 - val_msssim_loss: 0.0534 - val_vgg16_loss: 0.0722 - val_classification_loss_single: 2.4655
# Epoch 10/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0429 - msssim_loss: 0.0429 - vgg16_loss: 0.0591 - classification_loss_single: 3.7259
# 500/500 [==============================] - 962s 2s/step - loss: 0.0429 - msssim_loss: 0.0429 - vgg16_loss: 0.0591 - classification_loss_single: 3.7254 - val_loss: 0.0529 - val_msssim_loss: 0.0528 - val_vgg16_loss: 0.0718 - val_classification_loss_single: 2.4198
# Epoch 11/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0423 - msssim_loss: 0.0423 - vgg16_loss: 0.0584 - classification_loss_single: 3.7233
# 500/500 [==============================] - 963s 2s/step - loss: 0.0423 - msssim_loss: 0.0423 - vgg16_loss: 0.0584 - classification_loss_single: 3.7227 - val_loss: 0.0524 - val_msssim_loss: 0.0524 - val_vgg16_loss: 0.0710 - val_classification_loss_single: 2.3536
# Epoch 12/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0421 - msssim_loss: 0.0421 - vgg16_loss: 0.0579 - classification_loss_single: 3.6941
# 500/500 [==============================] - 962s 2s/step - loss: 0.0421 - msssim_loss: 0.0421 - vgg16_loss: 0.0579 - classification_loss_single: 3.6948 - val_loss: 0.0518 - val_msssim_loss: 0.0518 - val_vgg16_loss: 0.0697 - val_classification_loss_single: 2.3456
# Epoch 13/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0415 - msssim_loss: 0.0415 - vgg16_loss: 0.0573 - classification_loss_single: 3.6655
# 500/500 [==============================] - 962s 2s/step - loss: 0.0415 - msssim_loss: 0.0415 - vgg16_loss: 0.0573 - classification_loss_single: 3.6649 - val_loss: 0.0511 - val_msssim_loss: 0.0511 - val_vgg16_loss: 0.0694 - val_classification_loss_single: 2.2957
# Epoch 14/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0412 - msssim_loss: 0.0412 - vgg16_loss: 0.0568 - classification_loss_single: 3.6602
# 500/500 [==============================] - 962s 2s/step - loss: 0.0412 - msssim_loss: 0.0412 - vgg16_loss: 0.0567 - classification_loss_single: 3.6600 - val_loss: 0.0510 - val_msssim_loss: 0.0510 - val_vgg16_loss: 0.0690 - val_classification_loss_single: 2.2713
# Epoch 15/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0409 - msssim_loss: 0.0409 - vgg16_loss: 0.0563 - classification_loss_single: 3.6556
# 500/500 [==============================] - 962s 2s/step - loss: 0.0409 - msssim_loss: 0.0409 - vgg16_loss: 0.0563 - classification_loss_single: 3.6558 - val_loss: 0.0507 - val_msssim_loss: 0.0507 - val_vgg16_loss: 0.0693 - val_classification_loss_single: 2.2545
# Epoch 16/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0407 - msssim_loss: 0.0407 - vgg16_loss: 0.0560 - classification_loss_single: 3.6400
# 500/500 [==============================] - 963s 2s/step - loss: 0.0407 - msssim_loss: 0.0407 - vgg16_loss: 0.0560 - classification_loss_single: 3.6407 - val_loss: 0.0502 - val_msssim_loss: 0.0502 - val_vgg16_loss: 0.0686 - val_classification_loss_single: 2.2510
# Epoch 17/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0405 - msssim_loss: 0.0405 - vgg16_loss: 0.0557 - classification_loss_single: 3.6244
# 500/500 [==============================] - 962s 2s/step - loss: 0.0405 - msssim_loss: 0.0405 - vgg16_loss: 0.0557 - classification_loss_single: 3.6241 - val_loss: 0.0502 - val_msssim_loss: 0.0502 - val_vgg16_loss: 0.0681 - val_classification_loss_single: 2.2317
# Epoch 18/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0403 - msssim_loss: 0.0403 - vgg16_loss: 0.0553 - classification_loss_single: 3.6109
# 500/500 [==============================] - 962s 2s/step - loss: 0.0403 - msssim_loss: 0.0403 - vgg16_loss: 0.0553 - classification_loss_single: 3.6106 - val_loss: 0.0500 - val_msssim_loss: 0.0500 - val_vgg16_loss: 0.0688 - val_classification_loss_single: 2.2519
# Epoch 19/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0401 - msssim_loss: 0.0401 - vgg16_loss: 0.0551 - classification_loss_single: 3.6207
# 500/500 [==============================] - 962s 2s/step - loss: 0.0401 - msssim_loss: 0.0401 - vgg16_loss: 0.0551 - classification_loss_single: 3.6211 - val_loss: 0.0497 - val_msssim_loss: 0.0497 - val_vgg16_loss: 0.0683 - val_classification_loss_single: 2.2217
# Epoch 20/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0400 - msssim_loss: 0.0400 - vgg16_loss: 0.0550 - classification_loss_single: 3.5968
# 500/500 [==============================] - 963s 2s/step - loss: 0.0400 - msssim_loss: 0.0400 - vgg16_loss: 0.0550 - classification_loss_single: 3.5963 - val_loss: 0.0496 - val_msssim_loss: 0.0496 - val_vgg16_loss: 0.0679 - val_classification_loss_single: 2.1967
# Epoch 21/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0398 - msssim_loss: 0.0398 - vgg16_loss: 0.0547 - classification_loss_single: 3.6023
# 500/500 [==============================] - 963s 2s/step - loss: 0.0398 - msssim_loss: 0.0398 - vgg16_loss: 0.0547 - classification_loss_single: 3.6025 - val_loss: 0.0494 - val_msssim_loss: 0.0494 - val_vgg16_loss: 0.0668 - val_classification_loss_single: 2.1112
# Epoch 22/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0397 - msssim_loss: 0.0397 - vgg16_loss: 0.0546 - classification_loss_single: 3.5988
# 500/500 [==============================] - 962s 2s/step - loss: 0.0397 - msssim_loss: 0.0397 - vgg16_loss: 0.0546 - classification_loss_single: 3.5985 - val_loss: 0.0492 - val_msssim_loss: 0.0492 - val_vgg16_loss: 0.0671 - val_classification_loss_single: 2.1596
# Epoch 23/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0395 - msssim_loss: 0.0395 - vgg16_loss: 0.0544 - classification_loss_single: 3.5827
# 500/500 [==============================] - 962s 2s/step - loss: 0.0395 - msssim_loss: 0.0395 - vgg16_loss: 0.0544 - classification_loss_single: 3.5823 - val_loss: 0.0490 - val_msssim_loss: 0.0490 - val_vgg16_loss: 0.0673 - val_classification_loss_single: 2.1678
# Epoch 24/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0395 - msssim_loss: 0.0395 - vgg16_loss: 0.0543 - classification_loss_single: 3.5891
# 500/500 [==============================] - 962s 2s/step - loss: 0.0395 - msssim_loss: 0.0395 - vgg16_loss: 0.0543 - classification_loss_single: 3.5895 - val_loss: 0.0490 - val_msssim_loss: 0.0490 - val_vgg16_loss: 0.0665 - val_classification_loss_single: 2.0560
# Epoch 25/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0394 - msssim_loss: 0.0394 - vgg16_loss: 0.0542 - classification_loss_single: 3.5731
# 500/500 [==============================] - 962s 2s/step - loss: 0.0394 - msssim_loss: 0.0394 - vgg16_loss: 0.0542 - classification_loss_single: 3.5729 - val_loss: 0.0488 - val_msssim_loss: 0.0488 - val_vgg16_loss: 0.0665 - val_classification_loss_single: 2.1047
# Epoch 26/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0391 - msssim_loss: 0.0391 - vgg16_loss: 0.0538 - classification_loss_single: 3.5818
# 500/500 [==============================] - 961s 2s/step - loss: 0.0391 - msssim_loss: 0.0391 - vgg16_loss: 0.0538 - classification_loss_single: 3.5815 - val_loss: 0.0490 - val_msssim_loss: 0.0490 - val_vgg16_loss: 0.0663 - val_classification_loss_single: 2.1154
# Epoch 27/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0391 - msssim_loss: 0.0391 - vgg16_loss: 0.0538 - classification_loss_single: 3.5661
# 500/500 [==============================] - 962s 2s/step - loss: 0.0391 - msssim_loss: 0.0391 - vgg16_loss: 0.0538 - classification_loss_single: 3.5661 - val_loss: 0.0487 - val_msssim_loss: 0.0487 - val_vgg16_loss: 0.0665 - val_classification_loss_single: 2.0922
# Epoch 28/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0390 - msssim_loss: 0.0390 - vgg16_loss: 0.0536 - classification_loss_single: 3.5602
# 500/500 [==============================] - 962s 2s/step - loss: 0.0390 - msssim_loss: 0.0390 - vgg16_loss: 0.0536 - classification_loss_single: 3.5604 - val_loss: 0.0485 - val_msssim_loss: 0.0485 - val_vgg16_loss: 0.0661 - val_classification_loss_single: 2.1274
# Epoch 29/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0389 - msssim_loss: 0.0389 - vgg16_loss: 0.0535 - classification_loss_single: 3.5601
# 500/500 [==============================] - 961s 2s/step - loss: 0.0389 - msssim_loss: 0.0389 - vgg16_loss: 0.0535 - classification_loss_single: 3.5603 - val_loss: 0.0488 - val_msssim_loss: 0.0488 - val_vgg16_loss: 0.0664 - val_classification_loss_single: 2.1229
# Epoch 30/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0387 - msssim_loss: 0.0387 - vgg16_loss: 0.0533 - classification_loss_single: 3.5448
# 500/500 [==============================] - 962s 2s/step - loss: 0.0387 - msssim_loss: 0.0387 - vgg16_loss: 0.0533 - classification_loss_single: 3.5443 - val_loss: 0.0480 - val_msssim_loss: 0.0480 - val_vgg16_loss: 0.0666 - val_classification_loss_single: 2.1064
# Epoch 31/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0387 - msssim_loss: 0.0387 - vgg16_loss: 0.0532 - classification_loss_single: 3.5570
# 500/500 [==============================] - 962s 2s/step - loss: 0.0387 - msssim_loss: 0.0387 - vgg16_loss: 0.0532 - classification_loss_single: 3.5570 - val_loss: 0.0488 - val_msssim_loss: 0.0488 - val_vgg16_loss: 0.0651 - val_classification_loss_single: 2.0798
# Epoch 32/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0386 - msssim_loss: 0.0386 - vgg16_loss: 0.0530 - classification_loss_single: 3.5492
# 500/500 [==============================] - 962s 2s/step - loss: 0.0386 - msssim_loss: 0.0386 - vgg16_loss: 0.0530 - classification_loss_single: 3.5493 - val_loss: 0.0479 - val_msssim_loss: 0.0479 - val_vgg16_loss: 0.0655 - val_classification_loss_single: 2.0750
# Epoch 33/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0385 - msssim_loss: 0.0385 - vgg16_loss: 0.0529 - classification_loss_single: 3.5483
# 500/500 [==============================] - 962s 2s/step - loss: 0.0385 - msssim_loss: 0.0385 - vgg16_loss: 0.0529 - classification_loss_single: 3.5490 - val_loss: 0.0480 - val_msssim_loss: 0.0480 - val_vgg16_loss: 0.0662 - val_classification_loss_single: 2.1329
# Epoch 34/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0385 - msssim_loss: 0.0385 - vgg16_loss: 0.0529 - classification_loss_single: 3.5342
# 500/500 [==============================] - 962s 2s/step - loss: 0.0385 - msssim_loss: 0.0385 - vgg16_loss: 0.0528 - classification_loss_single: 3.5348 - val_loss: 0.0479 - val_msssim_loss: 0.0479 - val_vgg16_loss: 0.0656 - val_classification_loss_single: 2.0744
# Epoch 35/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0384 - msssim_loss: 0.0384 - vgg16_loss: 0.0528 - classification_loss_single: 3.5422
# 500/500 [==============================] - 962s 2s/step - loss: 0.0384 - msssim_loss: 0.0384 - vgg16_loss: 0.0528 - classification_loss_single: 3.5422 - val_loss: 0.0480 - val_msssim_loss: 0.0480 - val_vgg16_loss: 0.0657 - val_classification_loss_single: 2.0692
# Epoch 36/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0384 - msssim_loss: 0.0384 - vgg16_loss: 0.0527 - classification_loss_single: 3.5453
# 500/500 [==============================] - 962s 2s/step - loss: 0.0384 - msssim_loss: 0.0384 - vgg16_loss: 0.0527 - classification_loss_single: 3.5453 - val_loss: 0.0476 - val_msssim_loss: 0.0476 - val_vgg16_loss: 0.0650 - val_classification_loss_single: 2.0678
# Epoch 37/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0382 - msssim_loss: 0.0382 - vgg16_loss: 0.0525 - classification_loss_single: 3.5293
# 500/500 [==============================] - 963s 2s/step - loss: 0.0382 - msssim_loss: 0.0382 - vgg16_loss: 0.0525 - classification_loss_single: 3.5290 - val_loss: 0.0480 - val_msssim_loss: 0.0480 - val_vgg16_loss: 0.0656 - val_classification_loss_single: 2.1481
# Epoch 38/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0382 - msssim_loss: 0.0382 - vgg16_loss: 0.0523 - classification_loss_single: 3.5302
# 500/500 [==============================] - 962s 2s/step - loss: 0.0382 - msssim_loss: 0.0382 - vgg16_loss: 0.0523 - classification_loss_single: 3.5298 - val_loss: 0.0475 - val_msssim_loss: 0.0475 - val_vgg16_loss: 0.0647 - val_classification_loss_single: 2.0746
# Epoch 39/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0382 - msssim_loss: 0.0382 - vgg16_loss: 0.0523 - classification_loss_single: 3.5296
# 500/500 [==============================] - 962s 2s/step - loss: 0.0382 - msssim_loss: 0.0382 - vgg16_loss: 0.0523 - classification_loss_single: 3.5289 - val_loss: 0.0475 - val_msssim_loss: 0.0475 - val_vgg16_loss: 0.0648 - val_classification_loss_single: 2.0359
# Epoch 40/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0380 - msssim_loss: 0.0380 - vgg16_loss: 0.0522 - classification_loss_single: 3.5195
# 500/500 [==============================] - 962s 2s/step - loss: 0.0380 - msssim_loss: 0.0380 - vgg16_loss: 0.0522 - classification_loss_single: 3.5197 - val_loss: 0.0475 - val_msssim_loss: 0.0475 - val_vgg16_loss: 0.0647 - val_classification_loss_single: 2.0547
# Epoch 41/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0380 - msssim_loss: 0.0380 - vgg16_loss: 0.0522 - classification_loss_single: 3.5246
# 500/500 [==============================] - 963s 2s/step - loss: 0.0380 - msssim_loss: 0.0380 - vgg16_loss: 0.0522 - classification_loss_single: 3.5247 - val_loss: 0.0475 - val_msssim_loss: 0.0475 - val_vgg16_loss: 0.0642 - val_classification_loss_single: 2.0541
# Epoch 42/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0379 - msssim_loss: 0.0379 - vgg16_loss: 0.0520 - classification_loss_single: 3.5249
# 500/500 [==============================] - 962s 2s/step - loss: 0.0379 - msssim_loss: 0.0379 - vgg16_loss: 0.0520 - classification_loss_single: 3.5238 - val_loss: 0.0474 - val_msssim_loss: 0.0474 - val_vgg16_loss: 0.0645 - val_classification_loss_single: 2.0168
# Epoch 43/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0379 - msssim_loss: 0.0379 - vgg16_loss: 0.0519 - classification_loss_single: 3.5056
# 500/500 [==============================] - 962s 2s/step - loss: 0.0379 - msssim_loss: 0.0379 - vgg16_loss: 0.0519 - classification_loss_single: 3.5050 - val_loss: 0.0476 - val_msssim_loss: 0.0476 - val_vgg16_loss: 0.0652 - val_classification_loss_single: 2.1050
# Epoch 44/100
# 499/500 [============================>.] - ETA: 1s - loss: 0.0379 - msssim_loss: 0.0379 - vgg16_loss: 0.0519 - classification_loss_single: 3.5134
# 500/500 [==============================] - 962s 2s/step - loss: 0.0379 - msssim_loss: 0.0379 - vgg16_loss: 0.0519 - classification_loss_single: 3.5129 - val_loss: 0.0471 - val_msssim_loss: 0.0472 - val_vgg16_loss: 0.0636 - val_classification_loss_single: 2.0032
# Epoch 45/100
# 307/500 [=================>............] - ETA: 5:58 - loss: 0.0378 - msssim_loss: 0.0378 - vgg16_loss: 0.0517 - classification_loss_single: 3.4975

# %%
r = autoencoder.predict(x_test[:100])
plt.imshow(r[3])
print(np.mean(tf.image.ssim_multiscale(x_test[:len(r)], r, 1.0)))

# %% [markdown]
# ## Step 3. Benchmark against JPEG
# ### Step 3.1 Get JPEG baseline
# ### Step 3.2 Benchmark floating point model
# ### Step 3.3 Benchmark quantized model
# ### Step 3.4 Benchmark quantized embedding

# %%
# benchmark on jpeg images, takes about 10 minutes to run

#@ray.remote
def jpeg_compress(img, q, file_seg):
    # input/output image in [0, 1]
    
    def get_seg_size(file_values, seg_value):
        for i in range(1, len(file_values)):
            if (file_values[i-1] == int('0xff', 16)) and (file_values[i] == seg_value):
                return len(file_values) - (i-1)
        return int(-1e8)

    tmp_file = io.BytesIO()
    Image.fromarray((img*255.0).astype(np.uint8)).save(tmp_file, 'JPEG', quality=q, subsampling=0)
    if file_seg == 0:
        size = len(tmp_file.getvalue())
    elif file_seg == 1:
        size = get_seg_size(tmp_file.getvalue(), int('0xdb', 16)) # quantization table
    elif file_seg == 2:
        size = get_seg_size(tmp_file.getvalue(), int('0xc4', 16)) # huffman table
    elif file_seg == 3:
        size = get_seg_size(tmp_file.getvalue(), int('0xda', 16)) # start of scan

    img_compress = np.array(Image.open(tmp_file))/255.0
    tmp_file.close()
    return img_compress, size


def metric_msssim(image_in, image_out):
    return tf.image.ssim_multiscale(image_in.astype('float'), image_out.astype('float'), max_val=1.0).numpy()


def metric_classification(y_true, y_pred):
    out_true = car_model(y_true*2.0-1.0)
    out_pred = car_model(y_pred*2.0-1.0)
    onehot_true = tf.one_hot(tf.argmax(out_true, axis=1), depth = out_true.shape[1])
    acc = tf.keras.metrics.top_k_categorical_accuracy(onehot_true, out_pred, k=10)
    return acc


def benchmark_jpeg(x, metric_fun, file_seg=0):
    j_size = []
    j_result = []
    
    for q in range(0,30):
        print(q, end=',')
        #r = ray.get([jpeg_compress.remote(img, q) for img in x])
        r = [jpeg_compress(img, q, file_seg) for img in x]
        j_size.append( np.array(r)[:,1] )
        
        compressed_images = np.stack( np.array(r)[:,0] )
        batch_size = 32
        tmp_result = []
        for i in range(0,len(x),batch_size):
            tmp_result += list(metric_fun(x[i:i+batch_size], compressed_images[i:i+batch_size]))
        j_result.append(np.array(tmp_result))
    
    return j_result, j_size 

metric_list = [metric_msssim, vgg16_loss, metric_classification]
metric_eval = metric_list[eval_target]

j_bench_fn = "./Output/jpeg_%s.npy" % target_list[eval_target]
if os.path.exists(j_bench_fn):
    j_qual, j_size = np.load(j_bench_fn, allow_pickle=True)
else:
    j_qual, j_size = benchmark_jpeg(x_test[:128], metric_eval)
    np.save(j_bench_fn, [j_qual, j_size])

plt.figure(figsize=(4.5,3))
plt.plot( np.mean(j_qual, axis=1), np.mean(j_size, axis=1), '-r+', label='JPEG' )
plt.xlabel(target_list[eval_target]);plt.ylabel("Size/kB");plt.grid();plt.tight_layout();plt.legend()

# %%
#import keract
#keract.__version__
#activations = keract.get_activations(autoencoder, x_test[2][np.newaxis,:,:,:].astype('float64'))
#activations = keract.get_activations(enc_patch, x_test[2][np.newaxis,:112,:112,:])
#keract.display_activations(activations, cmap=None, save=False, directory='.', data_format='channels_last')

## !!! important parameter, adjust according to your GPU memory size
x_test_len = 64

ae_float_out = autoencoder.predict(x_test[:x_test_len], batch_size=32)
#ae_float_result = [metric_eval(x_test[i], ae_float_out[i]) for i in range(len(ae_float_out))]
ae_float_result = metric_eval(x_test[:len(ae_float_out)], ae_float_out)

print(np.mean(ae_float_result))

plt.figure(figsize=(4.5,3))
plt.plot( np.mean(j_qual, axis=1), np.mean(j_size, axis=1), '-r+', label='JPEG' )
plt.plot(np.mean(ae_float_result), embed_size[1]*2*4, 'b*', label='AE_float')  # assuming float16 for embedding -> 2Bytes, 4 patches
plt.xlabel(target_list[eval_target]);plt.ylabel("Size/kB");plt.grid();plt.tight_layout();plt.legend()

# %%
@ray.remote
def infer_q_tflite_single(fn, s):
    import tensorflow as tf
    interpreter = tf.compat.v1.lite.Interpreter(fn)
    interpreter.allocate_tensors()
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    interpreter.set_tensor(input_details[0]['index'], s)
    interpreter.invoke()
    return interpreter.get_tensor(output_details[0]['index'])

    
def infer_q_tflite_batch(fn, s):
    return np.array(ray.get([infer_q_tflite_single.remote(fn, s[i][np.newaxis, :, :, :]) for i in range(len(s))]))


save_q_model(enc_patch, "./Output/enc_patch.tflite", x_test[:,:112,:112,:])
patch_enc_quantized_out = [None]*4
patch_dec_quantized_out = [None]*4
for i in range(4):
    tmp_test = slice_image_4d(x_test[:x_test_len], i)
    patch_enc_quantized_out[i] = infer_q_tflite_batch("./Output/enc_patch.tflite", tmp_test)
    patch_dec_quantized_out[i] = dec_patch(patch_enc_quantized_out[i][:,0,:])
print("Finished infer.")

ae_quantized_out = combine_image_4d(patch_dec_quantized_out)
#ae_quantized_result = [metric_eval(x_test[i], ae_quantized_out[i]) for i in range(len(ae_quantized_out))]
ae_quantized_result = metric_eval(x_test[:len(ae_quantized_out)], ae_quantized_out)

plt.figure(figsize=(4.5,3))
plt.plot( np.mean(j_qual, axis=1), np.mean(j_size, axis=1), '-r+', label='JPEG' )
plt.plot(np.mean(ae_float_result), embed_size[1]*2*4, 'b*', label='AE_float')  # assuming float16 for embedding -> 2Bytes, 4 patches
plt.plot(np.mean(ae_quantized_result), embed_size[1]*1*4, 'gx', label='AE_quantized')  # int8 for embedding -> 1Byte, 4 patches
plt.xlabel(target_list[eval_target]);plt.ylabel("Size/kB");plt.grid();plt.tight_layout();plt.legend()

# %%
## Then run TFLite inference and quantize embedding
def quantize(d, Q_level):
    d_min, d_max = np.min(d), np.max(d)
    q = np.digitize(d, np.linspace(d_min, d_max, Q_level), right=True)
    s = d_max - d_min
    z = d_min
    return q, s, z, Q_level


def de_quantize(q, s, z, Q_level):
    d = [e/Q_level*s+z for e in q]
    return np.array(d)


#@ray.remote
def quantize_embedding(embed, Q_level):
    ## Data flow:   embed -> quantize -> huffman encode -> huffman decode -> de_quantize
    enc_q, s, z, _ = quantize(embed, Q_level)
    
    # huffman doesn't work well for low bits quantization
    from dahuffman import HuffmanCodec
    codec = HuffmanCodec.from_data([str(e) for e in enc_q])
    enc_huff = codec.encode([str(e) for e in enc_q])
    enc_huff_dec = [ int(x) for x in codec.decode(enc_huff)]
    #print("Compression size before/after and error:", len(embed), len(enc_huff), np.sum(np.abs(enc_huff_dec - enc_q)))

    enc_q_dq = de_quantize(enc_huff_dec, s, z, Q_level).reshape(embed.shape)
    #print("Mean quantization error and mean embed value:", np.mean(np.abs(embed - enc_q_dq)), np.mean(np.abs(embed)))
    return enc_q_dq, len(enc_huff)


tfl_embed_quant_result = []
tfl_embed_quant_size = []
output_images = []
for Q_level in [256, 192, 128, 96, 64, 48, 32, 24, 16, 12, 8, 6]:
    embed_quantized = [None]*4
    embed_quantized_size = [None]*4  
    patch_dec_quantized_out = [None]*4

    for i in range(4):
        #r = ray.get([quantize_embedding.remote(embed[0], Q_level) for embed in patch_enc_quantized_out[i]])
        r = [quantize_embedding(embed[0], Q_level) for embed in patch_enc_quantized_out[i]]
        embed_quantized[i] = np.array([e[0] for e in r]).astype(np.float32)
        embed_quantized_size[i] = np.array([e[1] for e in r])
        patch_dec_quantized_out[i] = dec_patch(embed_quantized[i])
    
    tfl_quantized = combine_image_4d(patch_dec_quantized_out)
    output_images.append(tfl_quantized)

    #embed_quantized_result = [metric_eval(x_test[i], tfl_quantized[i]) for i in range(len(tfl_quantized))]
    embed_quantized_result = metric_classification(x_test[:len(tfl_quantized)], tfl_quantized)
    tfl_embed_quant_result.append(np.mean(embed_quantized_result))
    tfl_embed_quant_size.append(np.sum(embed_quantized_size, axis=0)[:len(tfl_quantized)].mean())
    print(Q_level, tfl_embed_quant_result[-1], tfl_embed_quant_size[-1])
    
plt.figure(figsize=(4.5,3))
plt.plot(np.mean(j_qual, axis=1), np.mean(j_size, axis=1), '-r+', label='JPEG' )
plt.plot(np.mean(ae_float_result), embed_size[1]*2*4, 'b*', label='AE_float')  # assuming float16 for embedding -> 2Bytes, 4 patches
plt.plot(np.mean(ae_quantized_result), embed_size[1]*1*4, 'cx', label='AE_quantized')  # int8 for embedding -> 1Byte, 4 patches
#tfl_embed_quant_size = [4096, 4096, 3584, 3584, 3072, 3072, 2560, 2560, 2048, 1536]
plt.plot(tfl_embed_quant_result, tfl_embed_quant_size, '-gs', label='AE_embed_quantized')
plt.xlabel(target_list[eval_target]);plt.ylabel("Size/kB");plt.grid();plt.tight_layout();plt.legend()

# ratio plot. Ideally should be much > 1 for all x values
plt.figure(figsize=(4.5, 3))
ratio = np.interp(np.array(tfl_embed_quant_result), np.mean(j_qual, axis=1).astype(np.float32), np.mean(j_size, axis=1).astype(np.float32)) / np.array(tfl_embed_quant_size)
plt.plot(tfl_embed_quant_result, ratio,'-g')
plt.xlabel(target_list[eval_target]);plt.ylabel("Size/kB");plt.grid();plt.tight_layout();plt.legend()

# %%
plt.figure(figsize=(4.5,3))
plt.plot(np.mean(j_qual, axis=1), np.mean(j_size, axis=1), '-r+', label='JPEG' )
plt.plot(tfl_embed_quant_result, tfl_embed_quant_size, '-gs', label='AE_embed_quantized')
plt.xlabel(target_list[eval_target]);plt.ylabel("Size/kB");plt.grid();plt.tight_layout();plt.legend()
plt.ylim([0, 4000])
plt.savefig("./Output/%s_%s.pdf" % (dataset_name, target_list[eval_target]) )


result_all = {}
result_all['ae_quantized_out'] = ae_quantized_out
result_all['output_images'] = output_images
result_all['jpeg_x'] = np.mean(j_qual, axis=1) 
result_all['jpeg_y'] = np.mean(j_size, axis=1)
result_all['x'] = tfl_embed_quant_result
result_all['y'] = tfl_embed_quant_size
result_all['ratio'] = ratio
result_all['AE_float'] = [np.mean(ae_float_result), embed_size[1]*4*4]
result_all['AE_quantized'] = [np.mean(ae_quantized_result), embed_size[1]*1*4]

out_dir = "./Output/rd_result/"
os.system("mkdir -p " + out_dir)
np.save(out_dir + "%s_%s.npy" % (dataset_name, target_list[eval_target]), result_all)
